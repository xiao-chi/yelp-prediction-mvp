# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm 
import statsmodels.formula.api as smf

# %%
data = pd.read_csv(r"C:\Users\BigD\Desktop\UCL-Programming to BA\toronto_italian_pr2_restaurants_DONE.csv")
data.head()
# Out:
#                      address BikeParking BusinessAcceptsCreditCards Caters  \
# 0        185 Dundas Street W        True                       True   True
# 1  1228 Saint Clair Avenue W         NaN                       True    NaN
# 2         1185 King Street W        True                       True   True
# 3          370 Queens Quay W         NaN                       True    NaN
# 4             665 College St        True                       True   True
#
#   CoatCheck GoodForKids HappyHour  HasTV OutdoorSeating RestaurantsDelivery  \
# 0       NaN        True       NaN  False          False               False
# 1       NaN        True       NaN   True           True               False
# 2       NaN       False       NaN  False           True               False
# 3       NaN        True       NaN    NaN          False                 NaN
# 4       NaN        True       NaN   True           True                True
#
# ...

# %%
num_cols = ['positive_reviews', 'neutral_reviews', 'negative_reviews', 'OpenOnWeekends', 
            'NumberOfWeekdaysWithEarlyOpening', 'NumberOfWeekdaysWithLateClosing']
for col in num_cols:
    data[col] = data[col].replace(np.NaN, 0.0)

# %%
cols = ['ambience_romantic', 'ambience_intimate', 'ambience_classy', 'ambience_hipster' ,'ambience_touristy',
       'ambience_trendy', 'ambience_upscale', 'ambience_casual', 'good_for_dessert', 'good_for_latenight',
       'good_for_lunch', 'good_for_dinner', 'good_for_breakfast', 'good_for_brunch', 'parking_garage',
       'parking_validated', 'parking_lot', 'parking_valet', 'bestnight_monday', 'bestnight_tuesday', 
       'bestnight_wednesday', 'bestnight_thursday', 'bestnight_friday', 'bestnight_saturday', 'bestnight_sunday',
       'music_dj', 'music_background_music', 'music_no_music', 'music_karaoke', 'music_live', 'music_video', 
       'music_jukebox', 'parking_street','no_alcohol']
for col in cols:
    data[col] = data[col].replace(np.NaN, False)

# %%
Y = data["stars"]
X = data[['ambience_romantic', 'ambience_intimate', 'ambience_classy', 'ambience_hipster', 'ambience_touristy', 'ambience_trendy',
          'ambience_upscale', 'ambience_casual', 'good_for_dessert', 'good_for_latenight', 'good_for_lunch', 'good_for_dinner', 
          'good_for_breakfast', 'review_count', 'good_for_brunch', 'parking_garage', 'parking_street', 'parking_validated', 
          'parking_lot', 'parking_valet', 'bestnight_monday', 'full_bar', 'beer_and_wine', 'bestnight_tuesday', 'bestnight_wednesday', 
          'bestnight_thursday', 'bestnight_friday', 'bestnight_sunday', 'music_dj', 'music_background_music', 'music_karaoke', 'music_live', 
          'music_video', 'music_jukebox', 'smoking_outdoor', 'smoking_no', 'smoking_yes', 'wifi_free', 'wifi_no', 'wifi_paid', 'noise_very_loud', 
          'noise_loud', 'noise_quiet', 'noise_average', 'negative_reviews', 'neutral_reviews', 'positive_reviews', 'no_alcohol']]
X1 = sm.add_constant(X)
reg = sm.OLS(Y.astype(float), X1.astype(float)).fit()
reg.summary()
# Out:
# C:\Users\BigD\Anaconda3\lib\site-packages\statsmodels\base\model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# C:\Users\BigD\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\BigD\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\BigD\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.335
# Model:                            OLS   Adj. R-squared:                  0.241
# ...

# %%
X2 = X1.drop(['ambience_classy', 'good_for_dessert', 'parking_valet', 'bestnight_wednesday', 'bestnight_friday', 'negative_reviews', 'neutral_reviews','no_alcohol'], axis = 1)
reg = sm.OLS(Y.astype(float), X2.astype(float)).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                  0.250
# Method:                 Least Squares   F-statistic:                     4.192
# Date:                Thu, 13 Dec 2018   Prob (F-statistic):           1.87e-12
# Time:                        16:51:41   Log-Likelihood:                -283.39
# No. Observations:                 346   AIC:                             640.8
# Df Residuals:                     309   BIC:                             783.1
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X3 = X2.drop(['ambience_upscale','parking_street','ambience_touristy','beer_and_wine','music_video','music_jukebox'], axis = 1)
reg = sm.OLS(Y.astype(float), X3.astype(float)).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                  0.259
# Method:                 Least Squares   F-statistic:                     4.769
# Date:                Thu, 13 Dec 2018   Prob (F-statistic):           9.06e-14
# Time:                        16:51:41   Log-Likelihood:                -283.48
# No. Observations:                 346   AIC:                             633.0
# Df Residuals:                     313   BIC:                             759.9
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X4 = X3.drop(['ambience_intimate','good_for_brunch','parking_validated','music_live','smoking_no','wifi_no'], axis = 1)
reg = sm.OLS(Y.astype(float), X4.astype(float)).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.327
# Model:                            OLS   Adj. R-squared:                  0.272
# Method:                 Least Squares   F-statistic:                     5.949
# Date:                Thu, 13 Dec 2018   Prob (F-statistic):           6.53e-16
# Time:                        16:51:42   Log-Likelihood:                -283.80
# No. Observations:                 346   AIC:                             621.6
# Df Residuals:                     319   BIC:                             725.5
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X5 = X4.drop(['ambience_trendy','smoking_yes','noise_average'], axis = 1)
reg = sm.OLS(Y.astype(float), X5.astype(float)).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.326
# Model:                            OLS   Adj. R-squared:                  0.275
# Method:                 Least Squares   F-statistic:                     6.463
# Date:                Thu, 13 Dec 2018   Prob (F-statistic):           1.16e-16
# Time:                        16:51:42   Log-Likelihood:                -283.99
# No. Observations:                 346   AIC:                             618.0
# Df Residuals:                     321   BIC:                             714.1
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X6 = X5.drop(['noise_very_loud','noise_quiet'], axis = 1)
reg = sm.OLS(Y.astype(float), X6.astype(float)).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.325
# Model:                            OLS   Adj. R-squared:                  0.279
# Method:                 Least Squares   F-statistic:                     7.062
# Date:                Thu, 13 Dec 2018   Prob (F-statistic):           1.99e-17
# Time:                        16:51:42   Log-Likelihood:                -284.25
# No. Observations:                 346   AIC:                             614.5
# Df Residuals:                     323   BIC:                             703.0
# Df Model:                          22
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X7 = X6.drop(['good_for_lunch','bestnight_tuesday','wifi_free'], axis = 1)
reg = sm.OLS(Y.astype(float), X7.astype(float)).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     8.108
# Date:                Thu, 13 Dec 2018   Prob (F-statistic):           1.95e-18
# Time:                        16:51:42   Log-Likelihood:                -285.24
# No. Observations:                 346   AIC:                             610.5
# Df Residuals:                     326   BIC:                             687.4
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X8 = X7.drop(['parking_garage','music_karaoke','wifi_paid'], axis = 1)
reg = sm.OLS(Y.astype(float), X8.astype(float)).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.319
# Model:                            OLS   Adj. R-squared:                  0.284
# Method:                 Least Squares   F-statistic:                     9.030
# Date:                Thu, 13 Dec 2018   Prob (F-statistic):           3.33e-19
# Time:                        16:51:42   Log-Likelihood:                -285.77
# No. Observations:                 346   AIC:                             607.5
# Df Residuals:                     328   BIC:                             676.8
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X9 = X8.drop(['good_for_latenight','parking_lot'], axis = 1)
reg = sm.OLS(Y.astype(float), X9.astype(float)).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.313
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     10.01
# Date:                Thu, 13 Dec 2018   Prob (F-statistic):           1.23e-19
# Time:                        16:51:42   Log-Likelihood:                -287.32
# No. Observations:                 346   AIC:                             606.6
# Df Residuals:                     330   BIC:                             668.2
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X10 = X9.drop(['good_for_breakfast','bestnight_thursday','bestnight_sunday','music_background_music','smoking_outdoor'], axis = 1)
reg = sm.OLS(Y.astype(float), X10.astype(float)).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.273
# Method:                 Least Squares   F-statistic:                     13.96
# Date:                Thu, 13 Dec 2018   Prob (F-statistic):           1.26e-20
# Time:                        16:51:42   Log-Likelihood:                -291.93
# No. Observations:                 346   AIC:                             605.9
# Df Residuals:                     335   BIC:                             648.2
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...
