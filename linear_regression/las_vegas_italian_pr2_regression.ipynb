# %% [markdown]
# ## Linear Regression for Restaurants: LV Italian PR2
# Linear Regression done with backward elimination. Model assume alpha level of 0.10

# %%
import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm 
import matplotlib.pyplot as plt
from datetime import timedelta

# %%
data = pd.read_csv("../datasets/lasvegas_italian_pr2_restaurants.csv")
data.head()
# Out:
#    Unnamed: 0                                 address BikeParking  \
# 0           0                     2227 N Rampart Blvd        True
# 1           1                 1910 Village Center Cir        True
# 2           2                   3200 Las Vegas Blvd S       False
# 3           3  10690 Southern Highlands Pkwy, Ste 104         NaN
# 4           4                       9500 W Sahara Ave        True
#
#   BusinessAcceptsCreditCards Caters CoatCheck GoodForKids HappyHour HasTV  \
# 0                       True  False       NaN        True       NaN  True
# 1                       True   True       NaN        True       NaN  True
# 2                       True   True     False        True      True  True
# 3                       True    NaN       NaN        True       NaN   NaN
# 4                       True   True       NaN        True       NaN  True
#
#   OutdoorSeating       ...        noise_very_loud price_range_1 price_range_2  \
# ...

# %%
Y = data["stars"]
X = data[['ambience_romantic','ambience_classy','ambience_hipster','ambience_touristy','ambience_trendy',\
         'ambience_trendy','ambience_upscale','ambience_casual','good_for_dessert','good_for_latenight',\
          'good_for_lunch', 'good_for_dinner', 'good_for_breakfast', 'review_count', 'good_for_brunch', \
          'parking_garage','parking_street', 'parking_validated', 'parking_lot','parking_valet', 'bestnight_monday',\
          'no_alcohol', 'full_bar', 'beer_and_wine', 'bestnight_tuesday','bestnight_wednesday', 'bestnight_thursday',\
          'bestnight_friday', 'bestnight_sunday', 'music_dj','music_background_music', 'music_karaoke', 'music_live',\
          'music_video', 'music_jukebox', 'smoking_outdoor', 'smoking_no', 'smoking_yes', 'wifi_free', 'wifi_no',\
          'wifi_paid', 'noise_very_loud', 'noise_loud', 'noise_quiet', 'noise_average',\
          'negative_reviews', 'neutral_reviews', 'positive_reviews']]         
# X = data[['neighborhood']]
X1 = sm.add_constant(X)
reg = sm.OLS(Y.astype(float), X1.astype(float)).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.447
# Model:                            OLS   Adj. R-squared:                  0.341
# Method:                 Least Squares   F-statistic:                     4.222
# Date:                Tue, 18 Dec 2018   Prob (F-statistic):           6.79e-13
# Time:                        18:17:35   Log-Likelihood:                -192.03
# No. Observations:                 269   AIC:                             472.1
# Df Residuals:                     225   BIC:                             630.2
# Df Model:                          43
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
#Rerun regression only with variables with higher p value from previous regression
Y = data["stars"]
X = data[['ambience_classy','ambience_trendy', 'good_for_dinner', 'review_count', 'good_for_brunch', \
          'parking_garage','parking_street', 'parking_lot','no_alcohol', 'full_bar', 'bestnight_friday', 'wifi_free', 
          'noise_quiet', 'negative_reviews']]         
X1 = sm.add_constant(X)
reg = sm.OLS(Y.astype(float), X1.astype(float)).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  stars   R-squared:                       0.367
# Model:                            OLS   Adj. R-squared:                  0.334
# Method:                 Least Squares   F-statistic:                     11.36
# Date:                Thu, 13 Dec 2018   Prob (F-statistic):           3.32e-19
# Time:                        16:34:54   Log-Likelihood:                -210.16
# No. Observations:                 269   AIC:                             448.3
# Df Residuals:                     255   BIC:                             498.7
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
