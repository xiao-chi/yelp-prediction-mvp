# %%
import pandas as pd
import pandasql as ps
import numpy as np
import math
import matplotlib.pyplot as plt   #Data visualisation libraries 
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('vegas_sme_dataset.csv')

# %%
# pd.options.display.max_rows = 9999
# pd.options.display.max_columns = 9999

df1 = df.drop(columns=['neighborhood', 'price_range_1', 'price_range_2', 'price_range_3', 'price_range_4',
                     'latitude', 'longitude', 'postal_code', 'music_no_music'])
df1.corr()
# Out:
#                                   review_count     stars  ambience_romantic  \
# review_count                          1.000000  0.207778          -0.005132
# stars                                 0.207778  1.000000           0.063004
# ambience_romantic                    -0.005132  0.063004           1.000000
# ambience_intimate                    -0.015734  0.069022           0.465754
# ambience_classy                       0.010338  0.109025           0.344596
# ambience_hipster                      0.102264  0.181128          -0.019467
# ambience_touristy                     0.151206 -0.063871          -0.021147
# ambience_trendy                       0.172993  0.230147           0.050290
# ambience_upscale                     -0.005497  0.034744           0.199378
# ambience_casual                       0.166869  0.069909          -0.124061
# good_for_dessert                      0.044749  0.023722          -0.006324
# good_for_latenight                   -0.022000 -0.028853          -0.026741
# good_for_lunch                        0.202332  0.075033          -0.053456
# good_for_dinner                       0.156699  0.097192           0.028512
# good_for_breakfast                    0.102975  0.095533          -0.006905
# good_for_brunch                       0.166099  0.195184          -0.031799
# parking_garage                        0.217176 -0.127553           0.075758
# parking_street                        0.042045  0.148696           0.017293
# parking_validated                     0.002453  0.028164           0.136884
# parking_lot                          -0.064487  0.177281           0.000878
# parking_valet                         0.107772  0.030081           0.093101
# TotalOpenTimeInWeek                   0.155415  0.028114           0.013556
# NumberOfWeekdaysWithEarlyOpening      0.037870  0.002080          -0.034661
# NumberOfWeekdaysWithLateClosing       0.171885 -0.043858          -0.032828
# OpenOnWeekends                        0.214230  0.132634          -0.018746
# bestnight_monday                     -0.046005 -0.024180          -0.020820
# bestnight_tuesday                     0.029689  0.016399          -0.020153
# bestnight_wednesday                  -0.040479  0.021712          -0.021147
# bestnight_thursday                   -0.045715 -0.029317          -0.032520
# bestnight_friday                      0.060457  0.093602          -0.021948
# bestnight_saturday                    0.024654  0.072285           0.006083
# bestnight_sunday                      0.063225  0.080983           0.045010
# music_dj                             -0.056317  0.006772          -0.015656
# music_background_music               -0.010139 -0.008941           0.025981
# music_karaoke                        -0.045488 -0.010056          -0.010088
# music_live                           -0.013062 -0.021842          -0.016073
# music_video                          -0.038167 -0.051172          -0.007960
# music_jukebox                        -0.083013  0.017208          -0.021147
# full_bar                              0.088516 -0.041143           0.069630
# beer_and_wine                        -0.003599  0.082240          -0.032520
# none                                 -0.039228  0.015869          -0.046024
# smoking_outdoor                       0.034513  0.057747          -0.021147
# smoking_no                            0.104300  0.024158           0.041397
# smoking_yes                          -0.136178  0.032116          -0.042575
# wifi_free                             0.070410  0.152528          -0.035449
# wifi_no                               0.049978 -0.084197           0.038856
# wifi_paid                            -0.037994 -0.063573           0.072320
# noise_average                         0.175645  0.022395          -0.019505
# noise_loud                            0.021292 -0.059313          -0.031806
# noise_quiet                          -0.121414  0.079137           0.118703
# noise_very_loud                      -0.040671 -0.016818          -0.013396
# attire_casual                         0.070889 -0.027224           0.023329
# attire_dressy                        -0.034500 -0.005052          -0.007960
# negative_reviews                      0.841085 -0.067094          -0.034442
# neutral_reviews                       0.946214  0.066966          -0.026841
# positive_reviews                      0.988912  0.239742          -0.009661
#
#                                   ambience_intimate  ambience_classy  \
# review_count                              -0.015734         0.010338
# stars                                      0.069022         0.109025
# ambience_romantic                          0.465754         0.344596
# ambience_intimate                          1.000000         0.323402
# ambience_classy                            0.323402         1.000000
# ambience_hipster                          -0.020661         0.020097
# ambience_touristy                         -0.022444        -0.030058
# ambience_trendy                            0.083002         0.190520
# ambience_upscale                           0.187368         0.283396
# ambience_casual                           -0.109177        -0.098880
# good_for_dessert                           0.022530         0.041363
# good_for_latenight                        -0.004060        -0.058948
# good_for_lunch                            -0.065943        -0.020485
# good_for_dinner                            0.062851         0.022671
# good_for_breakfast                        -0.066625        -0.009815
# good_for_brunch                           -0.037105         0.035705
# parking_garage                             0.090248         0.087909
# parking_street                             0.012854         0.057727
# parking_validated                          0.128108         0.194568
# parking_lot                               -0.010913        -0.034445
# parking_valet                              0.044189         0.102408
# TotalOpenTimeInWeek                        0.003597         0.008699
# NumberOfWeekdaysWithEarlyOpening          -0.095966        -0.056472
# NumberOfWeekdaysWithLateClosing            0.002882         0.006386
# OpenOnWeekends                            -0.012163         0.019955
# bestnight_monday                          -0.022097        -0.029594
# bestnight_tuesday                         -0.021389         0.017615
# bestnight_wednesday                       -0.022444         0.014200
# bestnight_thursday                        -0.034514        -0.046224
# bestnight_friday                           0.001945         0.012262
# bestnight_saturday                         0.027739         0.008647
# bestnight_sunday                           0.038301         0.035444
# music_dj                                   0.061218         0.036382
# music_background_music                     0.021454         0.000046
# music_karaoke                             -0.010707        -0.014339
# music_live                                -0.017059        -0.022846
# music_video                               -0.008449        -0.011315
# music_jukebox                             -0.022444        -0.030058
# full_bar                                   0.073900         0.079915
# beer_and_wine                             -0.034514        -0.015775
# none                                      -0.048847        -0.065419
# smoking_outdoor                           -0.022444        -0.030058
# smoking_no                                 0.034735         0.086566
# smoking_yes                               -0.012222        -0.035683
# wifi_free                                  0.001070         0.003426
# wifi_no                                    0.003139         0.016961
# wifi_paid                                  0.066483         0.040886
# noise_average                             -0.063243        -0.008002
# noise_loud                                -0.033756        -0.014205
# noise_quiet                                0.154777         0.099311
# noise_very_loud                            0.076167        -0.019042
# attire_casual                             -0.028987        -0.047819
# attire_dressy                              0.141937         0.101976
# negative_reviews                          -0.040728        -0.040730
# neutral_reviews                           -0.031469        -0.011107
# positive_reviews                          -0.010151         0.015107
#
#                                   ambience_hipster  ambience_touristy  \
# review_count                              0.102264           0.151206
# stars                                     0.181128          -0.063871
# ambience_romantic                        -0.019467          -0.021147
# ambience_intimate                        -0.020661          -0.022444
# ambience_classy                           0.020097          -0.030058
# ambience_hipster                          1.000000          -0.040807
# ambience_touristy                        -0.040807           1.000000
# ambience_trendy                           0.292081           0.095091
# ambience_upscale                         -0.011884          -0.012909
# ambience_casual                           0.056135          -0.008070
# good_for_dessert                          0.070296           0.034791
# good_for_latenight                       -0.030036           0.042035
# good_for_lunch                            0.050996           0.083730
# good_for_dinner                           0.013224           0.118629
# good_for_breakfast                        0.101921          -0.007586
# good_for_brunch                           0.201861           0.014054
# parking_garage                           -0.018583           0.251435
# parking_street                            0.340606          -0.038512
# parking_validated                         0.060674           0.053528
# parking_lot                               0.021745          -0.159170
# parking_valet                             0.047965           0.054969
# TotalOpenTimeInWeek                       0.050156           0.166918
# NumberOfWeekdaysWithEarlyOpening         -0.080038          -0.039529
# NumberOfWeekdaysWithLateClosing          -0.019357           0.088966
# OpenOnWeekends                            0.020546           0.033471
# bestnight_monday                         -0.006549          -0.012486
# bestnight_tuesday                         0.065060          -0.042245
# bestnight_wednesday                       0.025494          -0.044329
# bestnight_thursday                       -0.039946          -0.004775
# bestnight_friday                          0.028853           0.040703
# bestnight_saturday                       -0.008276           0.020170
# bestnight_sunday                         -0.025347           0.044845
# music_dj                                 -0.030211           0.048567
# music_background_music                   -0.050010           0.099257
# music_karaoke                            -0.019467           0.041128
# music_live                                0.054652           0.005995
# music_video                              -0.015361           0.140561
# music_jukebox                            -0.040807          -0.013613
# full_bar                                 -0.022649           0.079831
# beer_and_wine                             0.028472          -0.004775
# none                                      0.034723          -0.063773
# smoking_outdoor                           0.058644           0.017103
# smoking_no                                0.053924           0.077155
# smoking_yes                              -0.082155          -0.054778
# wifi_free                                 0.121373          -0.071196
# wifi_no                                  -0.075507           0.108009
# wifi_paid                                -0.028540           0.011961
# noise_average                             0.078692          -0.044308
# noise_loud                                0.008291           0.170009
# noise_quiet                              -0.053646          -0.058276
# noise_very_loud                          -0.025850           0.019173
# attire_casual                             0.045017           0.048902
# attire_dressy                            -0.015361          -0.016687
# negative_reviews                         -0.004893           0.211292
# neutral_reviews                           0.028572           0.190289
# positive_reviews                          0.096078           0.137550
#
#                                   ambience_trendy  ambience_upscale  \
# review_count                             0.172993         -0.005497
# stars                                    0.230147          0.034744
# ambience_romantic                        0.050290          0.199378
# ambience_intimate                        0.083002          0.187368
# ambience_classy                          0.190520          0.283396
# ambience_hipster                         0.292081         -0.011884
# ambience_touristy                        0.095091         -0.012909
# ambience_trendy                          1.000000          0.115905
# ambience_upscale                         0.115905          1.000000
# ambience_casual                         -0.022868         -0.003655
# good_for_dessert                         0.131752          0.089846
# good_for_latenight                       0.038340          0.013652
# good_for_lunch                           0.047161          0.004444
# good_for_dinner                          0.144551         -0.018382
# good_for_breakfast                      -0.013636          0.007153
# good_for_brunch                          0.187128         -0.036785
# parking_garage                           0.075927          0.097201
# parking_street                           0.258430          0.058008
# parking_validated                       -0.028938         -0.005327
# parking_lot                             -0.038728         -0.060780
# parking_valet                            0.057394          0.048265
# TotalOpenTimeInWeek                      0.116660          0.020699
# NumberOfWeekdaysWithEarlyOpening        -0.113269         -0.013938
# NumberOfWeekdaysWithLateClosing          0.092700          0.001658
# OpenOnWeekends                           0.090050          0.028583
# bestnight_monday                        -0.027149         -0.012710
# bestnight_tuesday                        0.062686         -0.012303
# bestnight_wednesday                      0.012479         -0.012909
# bestnight_thursday                      -0.008390         -0.019852
# bestnight_friday                         0.119868         -0.032063
# bestnight_saturday                       0.090004          0.015955
# bestnight_sunday                         0.109327          0.043815
# music_dj                                 0.084886         -0.009557
# music_background_music                   0.086164         -0.015821
# music_karaoke                            0.050290         -0.006158
# music_live                               0.000067         -0.009812
# music_video                              0.026466         -0.004859
# music_jukebox                           -0.028827         -0.012909
# full_bar                                 0.106424          0.042506
# beer_and_wine                            0.034235         -0.019852
# none                                    -0.108657         -0.028096
# smoking_outdoor                          0.157050         -0.012909
# smoking_no                               0.124351          0.041146
# smoking_yes                             -0.083256         -0.025990
# wifi_free                                0.158663          0.014311
# wifi_no                                 -0.094362         -0.042022
# wifi_paid                               -0.020161          0.132775
# noise_average                            0.064158         -0.051434
# noise_loud                               0.024727         -0.019416
# noise_quiet                             -0.011222          0.142021
# noise_very_loud                         -0.012654         -0.008178
# attire_casual                            0.020687          0.014241
# attire_dressy                            0.026466         -0.004859
# negative_reviews                         0.044558         -0.011469
# neutral_reviews                          0.091397         -0.006459
# positive_reviews                         0.182775         -0.003582
#
#                                   ambience_casual        ...         \
# review_count                             0.166869        ...
# stars                                    0.069909        ...
# ambience_romantic                       -0.124061        ...
# ambience_intimate                       -0.109177        ...
# ambience_classy                         -0.098880        ...
# ambience_hipster                         0.056135        ...
# ambience_touristy                       -0.008070        ...
# ambience_trendy                         -0.022868        ...
# ambience_upscale                        -0.003655        ...
# ambience_casual                          1.000000        ...
# good_for_dessert                         0.191824        ...
# good_for_latenight                       0.167987        ...
# good_for_lunch                           0.509875        ...
# good_for_dinner                          0.300218        ...
# good_for_breakfast                       0.264170        ...
# good_for_brunch                          0.195575        ...
# parking_garage                           0.088491        ...
# parking_street                           0.053039        ...
# parking_validated                       -0.068025        ...
# parking_lot                              0.148643        ...
# parking_valet                           -0.016688        ...
# TotalOpenTimeInWeek                      0.015080        ...
# NumberOfWeekdaysWithEarlyOpening         0.180805        ...
# NumberOfWeekdaysWithLateClosing          0.260110        ...
# OpenOnWeekends                           0.369750        ...
# bestnight_monday                         0.014909        ...
# bestnight_tuesday                        0.062958        ...
# bestnight_wednesday                      0.045687        ...
# bestnight_thursday                       0.066993        ...
# bestnight_friday                         0.109590        ...
# bestnight_saturday                       0.110716        ...
# bestnight_sunday                         0.077253        ...
# music_dj                                -0.199207        ...
# music_background_music                  -0.007914        ...
# music_karaoke                           -0.069565        ...
# music_live                               0.002038        ...
# music_video                             -0.084993        ...
# music_jukebox                           -0.021510        ...
# full_bar                                 0.031678        ...
# beer_and_wine                            0.168695        ...
# none                                     0.039461        ...
# smoking_outdoor                         -0.021510        ...
# smoking_no                               0.115769        ...
# smoking_yes                              0.032543        ...
# wifi_free                                0.282622        ...
# wifi_no                                  0.019186        ...
# wifi_paid                               -0.033842        ...
# noise_average                            0.393159        ...
# noise_loud                               0.003091        ...
# noise_quiet                             -0.174580        ...
# noise_very_loud                         -0.035518        ...
# attire_casual                            0.239245        ...
# attire_dressy                           -0.119394        ...
# negative_reviews                         0.203582        ...
# neutral_reviews                          0.180639        ...
# positive_reviews                         0.154302        ...
#
#                                   wifi_paid  noise_average  noise_loud  \
# review_count                      -0.037994       0.175645    0.021292
# stars                             -0.063573       0.022395   -0.059313
# ambience_romantic                  0.072320      -0.019505   -0.031806
# ambience_intimate                  0.066483      -0.063243   -0.033756
# ambience_classy                    0.040886      -0.008002   -0.014205
# ambience_hipster                  -0.028540       0.078692    0.008291
# ambience_touristy                  0.011961      -0.044308    0.170009
# ambience_trendy                   -0.020161       0.064158    0.024727
# ambience_upscale                   0.132775      -0.051434   -0.019416
# ambience_casual                   -0.033842       0.393159    0.003091
# good_for_dessert                  -0.012327       0.092515   -0.009229
# good_for_latenight                -0.041745       0.070219    0.118010
# good_for_lunch                    -0.013273       0.299165   -0.028013
# good_for_dinner                   -0.090370       0.221562    0.015020
# good_for_breakfast                 0.081423       0.200196   -0.130352
# good_for_brunch                   -0.068709       0.161840   -0.121149
# parking_garage                     0.137462       0.076244    0.069415
# parking_street                    -0.043024       0.011172    0.036393
# parking_validated                 -0.012793      -0.040873    0.073108
# parking_lot                       -0.059349       0.187620   -0.114359
# parking_valet                      0.125599       0.024841    0.026191
# TotalOpenTimeInWeek                0.003936      -0.003869    0.044069
# NumberOfWeekdaysWithEarlyOpening   0.010824       0.124595   -0.073154
# NumberOfWeekdaysWithLateClosing   -0.075717       0.223842    0.059527
# OpenOnWeekends                    -0.021828       0.244549    0.023022
# bestnight_monday                  -0.030524       0.048256   -0.021989
# bestnight_tuesday                 -0.029546       0.055814    0.026420
# bestnight_wednesday               -0.031003       0.051502    0.040911
# bestnight_thursday                -0.018119       0.026579    0.089904
# bestnight_friday                  -0.034814       0.083248    0.087938
# bestnight_saturday                -0.017022       0.083863    0.078937
# bestnight_sunday                   0.003666       0.125904   -0.014148
# music_dj                          -0.022953      -0.136801    0.121672
# music_background_music             0.033615       0.083917   -0.045846
# music_karaoke                     -0.014790      -0.075006    0.099066
# music_live                        -0.023564      -0.057604    0.060531
# music_video                       -0.011671      -0.019770   -0.025097
# music_jukebox                     -0.031003       0.065189   -0.045155
# full_bar                           0.046584       0.167038    0.043500
# beer_and_wine                     -0.018119       0.064244   -0.028514
# none                              -0.044603      -0.037069    0.003804
# smoking_outdoor                   -0.031003      -0.057995    0.126976
# smoking_no                        -0.026779       0.068516    0.046273
# smoking_yes                       -0.014205       0.053997    0.022713
# wifi_free                         -0.162980       0.192098   -0.053988
# wifi_no                           -0.100923       0.056263    0.071340
# wifi_paid                          1.000000      -0.040562    0.043661
# noise_average                     -0.040562       1.000000   -0.498942
# noise_loud                         0.043661      -0.498942    1.000000
# noise_quiet                        0.026625      -0.436119   -0.087649
# noise_very_loud                    0.046459      -0.210151   -0.042235
# attire_casual                     -0.005103       0.215708    0.014499
# attire_dressy                     -0.011671      -0.089841    0.029979
# negative_reviews                  -0.021606       0.166378    0.068148
# neutral_reviews                   -0.026907       0.166644    0.044442
# positive_reviews                  -0.038220       0.166309    0.014963
#
#                                   noise_quiet  noise_very_loud  attire_casual  \
# review_count                        -0.121414        -0.040671       0.070889
# stars                                0.079137        -0.016818      -0.027224
# ambience_romantic                    0.118703        -0.013396       0.023329
# ambience_intimate                    0.154777         0.076167      -0.028987
# ambience_classy                      0.099311        -0.019042      -0.047819
# ambience_hipster                    -0.053646        -0.025850       0.045017
# ambience_touristy                   -0.058276         0.019173       0.048902
# ambience_trendy                     -0.011222        -0.012654       0.020687
# ambience_upscale                     0.142021        -0.008178       0.014241
# ambience_casual                     -0.174580        -0.035518       0.239245
# good_for_dessert                    -0.032842        -0.028558       0.064574
# good_for_latenight                  -0.097906        -0.029920       0.116674
# good_for_lunch                      -0.090683        -0.056172       0.280703
# good_for_dinner                     -0.102416        -0.071760       0.213228
# good_for_breakfast                  -0.000121        -0.040965       0.145166
# good_for_brunch                      0.021067        -0.058423       0.126505
# parking_garage                      -0.034702         0.042541       0.071187
# parking_street                      -0.026754        -0.003579      -0.016315
# parking_validated                    0.032272        -0.011587       0.020178
# parking_lot                          0.016987        -0.075052       0.094279
# parking_valet                       -0.010126         0.051738      -0.037170
# TotalOpenTimeInWeek                 -0.042221         0.050295      -0.011452
# NumberOfWeekdaysWithEarlyOpening    -0.004105        -0.100838       0.081010
# NumberOfWeekdaysWithLateClosing     -0.180170        -0.023365       0.142071
# OpenOnWeekends                      -0.061169        -0.087085       0.113615
# bestnight_monday                     0.015922        -0.027647       0.048146
# bestnight_tuesday                   -0.030362        -0.026762      -0.012137
# bestnight_wednesday                 -0.034190        -0.028081      -0.007297
# bestnight_thursday                  -0.056476         0.021835      -0.040786
# bestnight_friday                    -0.109264         0.046256      -0.044091
# bestnight_saturday                  -0.102483         0.065139      -0.024247
# bestnight_sunday                    -0.066184         0.014072       0.063483
# music_dj                            -0.011234         0.292229      -0.187156
# music_background_music               0.008871         0.004966       0.059931
# music_karaoke                        0.021034         0.082411       0.023329
# music_live                          -0.013172         0.161830       0.037168
# music_video                         -0.021937         0.110389       0.018408
# music_jukebox                       -0.058276        -0.028081      -0.007297
# full_bar                            -0.098506         0.031422       0.080962
# beer_and_wine                        0.026376        -0.010674       0.036539
# none                                 0.103973        -0.010804       0.091471
# smoking_outdoor                     -0.034190         0.066428      -0.007297
# smoking_no                          -0.085838         0.069771      -0.020920
# smoking_yes                         -0.049755        -0.003509      -0.043440
# wifi_free                           -0.003729        -0.013557       0.188741
# wifi_no                             -0.012675        -0.030122       0.037704
# wifi_paid                            0.026625         0.046459      -0.005103
# noise_average                       -0.436119        -0.210151       0.215708
# noise_loud                          -0.087649        -0.042235       0.014499
# noise_quiet                          1.000000        -0.036917       0.020219
# noise_very_loud                     -0.036917         1.000000      -0.098711
# attire_casual                        0.020219        -0.098711       1.000000
# attire_dressy                        0.039718         0.110389      -0.341227
# negative_reviews                    -0.142512        -0.032267       0.088573
# neutral_reviews                     -0.129027        -0.034916       0.081127
# positive_reviews                    -0.111658        -0.039358       0.062117
#
#                                   attire_dressy  negative_reviews  \
# review_count                          -0.034500          0.841085
# stars                                 -0.005052         -0.067094
# ambience_romantic                     -0.007960         -0.034442
# ambience_intimate                      0.141937         -0.040728
# ambience_classy                        0.101976         -0.040730
# ambience_hipster                      -0.015361         -0.004893
# ambience_touristy                     -0.016687          0.211292
# ambience_trendy                        0.026466          0.044558
# ambience_upscale                      -0.004859         -0.011469
# ambience_casual                       -0.119394          0.203582
# good_for_dessert                      -0.032943          0.082518
# good_for_latenight                    -0.007152          0.025321
# good_for_lunch                        -0.070936          0.204018
# good_for_dinner                       -0.044907          0.161573
# good_for_breakfast                    -0.049535          0.076092
# good_for_brunch                       -0.011618          0.086542
# parking_garage                         0.020261          0.272737
# parking_street                         0.035727         -0.016500
# parking_validated                     -0.006885         -0.008806
# parking_lot                           -0.015159         -0.118428
# parking_valet                          0.186435          0.106066
# TotalOpenTimeInWeek                   -0.001179          0.141050
# NumberOfWeekdaysWithEarlyOpening      -0.071349          0.086360
# NumberOfWeekdaysWithLateClosing       -0.076389          0.242167
# OpenOnWeekends                        -0.045835          0.222170
# bestnight_monday                      -0.016429         -0.041446
# bestnight_tuesday                     -0.015902          0.029406
# bestnight_wednesday                   -0.016687         -0.035832
# bestnight_thursday                     0.028429          0.001774
# bestnight_friday                       0.074359          0.040998
# bestnight_saturday                     0.071258          0.016221
# bestnight_sunday                      -0.027844          0.025330
# music_dj                               0.300133         -0.056015
# music_background_music                -0.020450         -0.023226
# music_karaoke                         -0.007960         -0.054697
# music_live                            -0.012683          0.004490
# music_video                           -0.006281         -0.035714
# music_jukebox                         -0.016687         -0.088967
# full_bar                               0.054944          0.113661
# beer_and_wine                         -0.025661         -0.013105
# none                                  -0.036317         -0.057579
# smoking_outdoor                        0.061937          0.043213
# smoking_no                            -0.028899          0.094462
# smoking_yes                            0.054633         -0.138440
# wifi_free                             -0.023989          0.039164
# wifi_no                                0.013665          0.092572
# wifi_paid                             -0.011671         -0.021606
# noise_average                         -0.089841          0.166378
# noise_loud                             0.029979          0.068148
# noise_quiet                            0.039718         -0.142512
# noise_very_loud                        0.110389         -0.032267
# attire_casual                         -0.341227          0.088573
# attire_dressy                          1.000000         -0.040491
# negative_reviews                      -0.040491          1.000000
# neutral_reviews                       -0.035327          0.941256
# positive_reviews                      -0.031480          0.792852
#
#                                   neutral_reviews  positive_reviews
# review_count                             0.946214          0.988912
# stars                                    0.066966          0.239742
# ambience_romantic                       -0.026841         -0.009661
# ambience_intimate                       -0.031469         -0.010151
# ambience_classy                         -0.011107          0.015107
# ambience_hipster                         0.028572          0.096078
# ambience_touristy                        0.190289          0.137550
# ambience_trendy                          0.091397          0.182775
# ambience_upscale                        -0.006459         -0.003582
# ambience_casual                          0.180639          0.154302
# good_for_dessert                         0.037304          0.039832
# good_for_latenight                       0.001146         -0.028986
# good_for_lunch                           0.189495          0.190220
# good_for_dinner                          0.133808          0.145781
# good_for_breakfast                       0.102042          0.105531
# good_for_brunch                          0.122877          0.174558
# parking_garage                           0.269037          0.201873
# parking_street                          -0.014363          0.046345
# parking_validated                       -0.005912          0.006050
# parking_lot                             -0.115974         -0.053482
# parking_valet                            0.099023          0.100291
# TotalOpenTimeInWeek                      0.139427          0.145240
# NumberOfWeekdaysWithEarlyOpening         0.073086          0.030295
# NumberOfWeekdaysWithLateClosing          0.200406          0.149534
# OpenOnWeekends                           0.208578          0.204590
# bestnight_monday                        -0.043815         -0.042571
# bestnight_tuesday                        0.015949          0.019030
# bestnight_wednesday                     -0.047415         -0.040259
# bestnight_thursday                      -0.023390         -0.048449
# bestnight_friday                         0.034879          0.053596
# bestnight_saturday                       0.011856          0.018486
# bestnight_sunday                         0.030207          0.060241
# music_dj                                -0.055194         -0.052601
# music_background_music                  -0.002792         -0.005391
# music_karaoke                           -0.048295         -0.041200
# music_live                              -0.019733         -0.027264
# music_video                             -0.034360         -0.036658
# music_jukebox                           -0.084576         -0.076627
# full_bar                                 0.097094          0.076813
# beer_and_wine                            0.003735         -0.005221
# none                                    -0.052585         -0.028125
# smoking_outdoor                          0.026907          0.036324
# smoking_no                               0.083635          0.087165
# smoking_yes                             -0.132483         -0.126313
# wifi_free                                0.028502          0.070069
# wifi_no                                  0.094433          0.042390
# wifi_paid                               -0.026907         -0.038220
# noise_average                            0.166644          0.166309
# noise_loud                               0.044442          0.014963
# noise_quiet                             -0.129027         -0.111658
# noise_very_loud                         -0.034916         -0.039358
# attire_casual                            0.081127          0.062117
# attire_dressy                           -0.035327         -0.031480
# negative_reviews                         0.941256          0.792852
# neutral_reviews                          1.000000          0.920436
# positive_reviews                         0.920436          1.000000
#
# [56 rows x 56 columns]

# %%
df2 = df1.drop(columns = ['stars'])
corr = df2.corr().abs()

s = corr.unstack()
so = s.sort_values(kind="quicksort")
so = so[so != 1.0]
s_1 = so[so <= 0.5]
s_2 = so[so > 0.5]

s_1 = pd.DataFrame({'vars':s_1.index, 'corr':s_1.values})

s_1[['var1','var2']] = pd.DataFrame(s_1.vars.values.tolist(), index= s_1.index)
s_1 = s_1.iloc[:,1:]

s_2 = pd.DataFrame({'vars':s_2.index, 'corr':s_2.values})

s_2[['var1','var2']] = pd.DataFrame(s_2.vars.values.tolist(), index= s_2.index)
s_2 = s_2.iloc[:,1:]

s_1.sort_values(by=['var1'])
# Out:
#           corr                              var1  \
# 1345  0.046398  NumberOfWeekdaysWithEarlyOpening
# 240   0.009480  NumberOfWeekdaysWithEarlyOpening
# 1926  0.084112  NumberOfWeekdaysWithEarlyOpening
# 773   0.025607  NumberOfWeekdaysWithEarlyOpening
# 1354  0.047147  NumberOfWeekdaysWithEarlyOpening
# 2178  0.107674  NumberOfWeekdaysWithEarlyOpening
# 1890  0.081010  NumberOfWeekdaysWithEarlyOpening
# 2616  0.180805  NumberOfWeekdaysWithEarlyOpening
# 97    0.004105  NumberOfWeekdaysWithEarlyOpening
# 2469  0.147563  NumberOfWeekdaysWithEarlyOpening
# 1880  0.080038  NumberOfWeekdaysWithEarlyOpening
# 1498  0.055184  NumberOfWeekdaysWithEarlyOpening
# 2226  0.113269  NumberOfWeekdaysWithEarlyOpening
# 1521  0.056472  NumberOfWeekdaysWithEarlyOpening
# 2177  0.107201  NumberOfWeekdaysWithEarlyOpening
# 279   0.010824  NumberOfWeekdaysWithEarlyOpening
# 2341  0.129337  NumberOfWeekdaysWithEarlyOpening
# 1571  0.059621  NumberOfWeekdaysWithEarlyOpening
# 1784  0.073086  NumberOfWeekdaysWithEarlyOpening
# 1768  0.071349  NumberOfWeekdaysWithEarlyOpening
# 1750  0.070568  NumberOfWeekdaysWithEarlyOpening
# 1735  0.069733  NumberOfWeekdaysWithEarlyOpening
# 1607  0.061305  NumberOfWeekdaysWithEarlyOpening
# 2310  0.124595  NumberOfWeekdaysWithEarlyOpening
# 1696  0.067003  NumberOfWeekdaysWithEarlyOpening
# 2301  0.122984  NumberOfWeekdaysWithEarlyOpening
# 1686  0.066420  NumberOfWeekdaysWithEarlyOpening
# 2841  0.277719  NumberOfWeekdaysWithEarlyOpening
# 2833  0.272277  NumberOfWeekdaysWithEarlyOpening
# 1789  0.073154  NumberOfWeekdaysWithEarlyOpening
# ...        ...                               ...
# 804   0.026625                         wifi_paid
# 2317  0.125599                         wifi_paid
# 83    0.003666                         wifi_paid
# 1281  0.043661                         wifi_paid
# 1691  0.066483                         wifi_paid
# 2125  0.100923                         wifi_paid
# 1030  0.034814                         wifi_paid
# 2362  0.132775                         wifi_paid
# 597   0.020161                         wifi_paid
# 1203  0.040886                         wifi_paid
# 415   0.014205                         wifi_paid
# 1347  0.046459                         wifi_paid
# 1348  0.046584                         wifi_paid
# 529   0.018119                         wifi_paid
# 890   0.029546                         wifi_paid
# 308   0.011671                         wifi_paid
# 1270  0.043024                         wifi_paid
# 506   0.017022                         wifi_paid
# 921   0.030524                         wifi_paid
# 311   0.011671                         wifi_paid
# 375   0.013273                         wifi_paid
# 923   0.031003                         wifi_paid
# 2393  0.137462                         wifi_paid
# 1182  0.040562                         wifi_paid
# 924   0.031003                         wifi_paid
# 278   0.010824                         wifi_paid
# 1302  0.044603                         wifi_paid
# 926   0.031003                         wifi_paid
# 527   0.018119                         wifi_paid
# 1228  0.041745                         wifi_paid
#
#                                   var2
# 1345                  bestnight_sunday
# 240                  parking_validated
# 1926                bestnight_saturday
# 773                      parking_valet
# 1354                        music_live
# 2178                       parking_lot
# 1890                     attire_casual
# 2616                   ambience_casual
# 97                         noise_quiet
# 2469   NumberOfWeekdaysWithLateClosing
# 1880                  ambience_hipster
# 1498            music_background_music
# 2226                   ambience_trendy
# 1521                   ambience_classy
# 2177                          music_dj
# 279                          wifi_paid
# 2341                    good_for_lunch
# 1571                    parking_garage
# 1784                   neutral_reviews
# 1768                     attire_dressy
# 1750                  bestnight_friday
# 1735                bestnight_thursday
# 1607                  good_for_dessert
# 2310                     noise_average
# 1696                  bestnight_monday
# 2301                     music_jukebox
# 1686                    parking_street
# 2841                       smoking_yes
# 2833                   good_for_brunch
# 1789                        noise_loud
# ...                                ...
# 804                        noise_quiet
# 2317                     parking_valet
# 83                    bestnight_sunday
# 1281                        noise_loud
# 1691                 ambience_intimate
# 2125                           wifi_no
# 1030                  bestnight_friday
# 2362                  ambience_upscale
# 597                    ambience_trendy
# 1203                   ambience_classy
# 415                        smoking_yes
# 1347                   noise_very_loud
# 1348                          full_bar
# 529                 bestnight_thursday
# 890                  bestnight_tuesday
# 308                      attire_dressy
# 1270                    parking_street
# 506                 bestnight_saturday
# 921                   bestnight_monday
# 311                        music_video
# 375                     good_for_lunch
# 923                    smoking_outdoor
# 2393                    parking_garage
# 1182                     noise_average
# 924                      music_jukebox
# 278   NumberOfWeekdaysWithEarlyOpening
# 1302                              none
# 926                bestnight_wednesday
# 527                      beer_and_wine
# 1228                good_for_latenight
#
# [2946 rows x 3 columns]

# %%
s_2.sort_values(by=['var1'])
# Out:
#         corr                             var1                             var2
# 5   0.593296  NumberOfWeekdaysWithLateClosing                   OpenOnWeekends
# 4   0.593296                   OpenOnWeekends  NumberOfWeekdaysWithLateClosing
# 1   0.509875                  ambience_casual                   good_for_lunch
# 11  0.781909                 bestnight_friday               bestnight_saturday
# 10  0.781909               bestnight_saturday                 bestnight_friday
# 7   0.660983                         full_bar                             none
# 2   0.538039               good_for_breakfast                  good_for_brunch
# 3   0.538039                  good_for_brunch               good_for_breakfast
# 0   0.509875                   good_for_lunch                  ambience_casual
# 12  0.792852                 negative_reviews                 positive_reviews
# 15  0.841085                 negative_reviews                     review_count
# 18  0.941256                 negative_reviews                  neutral_reviews
# 17  0.920436                  neutral_reviews                 positive_reviews
# 19  0.941256                  neutral_reviews                 negative_reviews
# 20  0.946214                  neutral_reviews                     review_count
# 6   0.660983                             none                         full_bar
# 22  0.988912                 positive_reviews                     review_count
# 13  0.792852                 positive_reviews                 negative_reviews
# 16  0.920436                 positive_reviews                  neutral_reviews
# 14  0.841085                     review_count                 negative_reviews
# 21  0.946214                     review_count                  neutral_reviews
# 23  0.988912                     review_count                 positive_reviews
# 8   0.758560                        wifi_free                          wifi_no
# 9   0.758560                          wifi_no                        wifi_free

# %%
len(s_1.var2.unique())
# Out:
# 55

# %%
len(s_2.var2.unique())
# Out:
# 16

# %%
import pandasql as ps


s_3 = ps.sqldf("select * from s_1 a left join s_2 b on a.var1 = b.var1 where b.var1 is null", locals())

s_3 = s_3.iloc[:,0:2]


s_3.var1.unique()
# Out:
# array(['TotalOpenTimeInWeek', 'music_background_music', 'ambience_classy',
#        'music_live', 'ambience_trendy', 'noise_quiet', 'parking_garage',
#        'bestnight_sunday', 'parking_lot', 'parking_validated',
#        'parking_valet', 'ambience_romantic', 'ambience_intimate',
#        'music_jukebox', 'good_for_latenight', 'attire_dressy',
#        'good_for_dessert', 'music_dj', 'beer_and_wine',
#        'bestnight_tuesday', 'ambience_upscale', 'bestnight_thursday',
#        'bestnight_monday', 'smoking_no', 'music_karaoke', 'noise_loud',
#        'noise_very_loud', 'smoking_yes', 'parking_street', 'wifi_paid',
#        'noise_average', 'NumberOfWeekdaysWithEarlyOpening',
#        'smoking_outdoor', 'music_video', 'ambience_touristy',
#        'ambience_hipster', 'attire_casual', 'bestnight_wednesday',
#        'good_for_dinner'], dtype=object)

# %%
import pandasql as ps


s_4 = ps.sqldf("select * from s_1 a left join s_2 b on a.var2 = b.var2 where b.var2 is null", locals())

s_4 = s_4.iloc[:,0:2]


s_3.var1.unique()
# Out:
# array(['TotalOpenTimeInWeek', 'music_background_music', 'ambience_classy',
#        'music_live', 'ambience_trendy', 'noise_quiet', 'parking_garage',
#        'bestnight_sunday', 'parking_lot', 'parking_validated',
#        'parking_valet', 'ambience_romantic', 'ambience_intimate',
#        'music_jukebox', 'good_for_latenight', 'attire_dressy',
#        'good_for_dessert', 'music_dj', 'beer_and_wine',
#        'bestnight_tuesday', 'ambience_upscale', 'bestnight_thursday',
#        'bestnight_monday', 'smoking_no', 'music_karaoke', 'noise_loud',
#        'noise_very_loud', 'smoking_yes', 'parking_street', 'wifi_paid',
#        'noise_average', 'NumberOfWeekdaysWithEarlyOpening',
#        'smoking_outdoor', 'music_video', 'ambience_touristy',
#        'ambience_hipster', 'attire_casual', 'bestnight_wednesday',
#        'good_for_dinner'], dtype=object)
